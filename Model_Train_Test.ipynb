# %% [markdown]
# <a href="https://colab.research.google.com/github/imdasrj98/Employee-Churn-Prediction/blob/master/Model_Train_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import sklearn
from keras.optimizers import SGD, RMSprop, Adadelta, Adagrad, Adam, Adamax
from keras.models import Sequential
from keras.layers.core import Dense, Activation, Flatten
import keras
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
# Out:
# Using TensorFlow backend.

# %%
df=pd.read_csv('/content/drive/My Drive/final_data_employee_churn.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Emp ID  satisfaction_level  ...  dept  salary  left
# 0           0       1                0.38  ...     7       1     1
# 1           1       2                0.80  ...     7       2     1
# 2           2       3                0.11  ...     7       2     1
# 3           3       4                0.72  ...     7       1     1
# 4           4       5                0.37  ...     7       1     1
#
# [5 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Emp ID', 'satisfaction_level', 'last_evaluation',
#        'number_project', 'average_montly_hours', 'time_spend_company',
#        'Work_accident', 'promotion_last_5years', 'dept', 'salary', 'left'],
#       dtype='object')

# %%
data=df[['satisfaction_level', 'last_evaluation',
       'number_project', 'average_montly_hours', 'time_spend_company',
       'Work_accident', 'promotion_last_5years', 'dept', 'salary', 'left']].values

# %%
x=data[:, 0: 9]
y=data[:, 9]

# %%
xtrain, xtest, ytrain, ytest=train_test_split(x, y, test_size=.2)

# %%
model = Sequential()
model.add(Dense(10, input_dim=9, activation= "relu"))
model.add(Dense(25, activation= "relu"))
model.add(Dense(50, activation= "relu"))
model.add(Dense(5, activation= "relu"))
model.add(Dense(1, activation="sigmoid"))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_6 (Dense)              (None, 10)                100
# _________________________________________________________________
# dense_7 (Dense)              (None, 25)                275
# _________________________________________________________________
# dense_8 (Dense)              (None, 50)                1300
# _________________________________________________________________
# dense_9 (Dense)              (None, 5)                 255
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 6
# ...
# Total params: 1,936
# Trainable params: 1,936
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = Adam()
model.compile(loss='binary_crossentropy', optimizer=opt,  metrics=['accuracy'])

# %%
model.fit(xtrain, ytrain, nb_epoch=1000, batch_size=32)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   """Entry point for launching an IPython kernel.
# Epoch 1/1000
# 11999/11999 [==============================] - 1s 65us/step - loss: 0.5711 - accuracy: 0.7586
# Epoch 2/1000
# 11999/11999 [==============================] - 1s 50us/step - loss: 0.5634 - accuracy: 0.7617
# Epoch 3/1000
# 11999/11999 [==============================] - 1s 48us/step - loss: 0.5578 - accuracy: 0.7617
# Epoch 4/1000
# 11999/11999 [==============================] - 1s 54us/step - loss: 0.5455 - accuracy: 0.7617
# Epoch 5/1000
# 11999/11999 [==============================] - 1s 50us/step - loss: 0.5304 - accuracy: 0.7617
# Epoch 6/1000
# 11999/11999 [==============================] - 1s 47us/step - loss: 0.4568 - accuracy: 0.7617
# Epoch 7/1000
# 11999/11999 [==============================] - 1s 48us/step - loss: 0.4085 - accuracy: 0.7617
# Epoch 8/1000
# ...

# %%
score, acc = model.evaluate(xtest, ytest)
# Out:
# 3000/3000 [==============================] - 0s 28us/step

# %%
print(acc)
# Out:
# 0.9653333425521851

# %%
predx=np.array([[1, 0.78, 0.98, 10, 250, 3, 3, 6, 3]])

# %%
ypred=model.predict(predx).reshape(-1)
print("calss : ", np.argmax(ypred))
# Out:
# calss :  0
